# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import cv2 #opencv Paket

# %%
img = cv2.imread("bild.jpg")

# %%
img
# Out:
# array([[[136, 135, 137],
#         [136, 135, 137],
#         [137, 136, 138],
#         ...,
#         [135, 133, 133],
#         [134, 132, 132],
#         [134, 131, 133]],
#
#        [[135, 134, 136],
#         [136, 135, 137],
#         [136, 135, 137],
#         ...,
#         [136, 134, 134],
#         [135, 133, 133],
#         [138, 135, 137]],
#
#        [[134, 133, 135],
#         [135, 134, 136],
#         [135, 134, 136],
#         ...,
#         [136, 134, 134],
#         [136, 134, 134],
#         [135, 132, 134]],
#
#        ...,
#
#        [[ 35,  33,  33],
#         [ 34,  32,  32],
#         [ 36,  34,  34],
#         ...,
#         [ 88,  87,  89],
#         [ 89,  88,  90],
#         [ 88,  87,  91]],
#
#        [[ 34,  32,  32],
#         [ 33,  31,  31],
#         [ 34,  32,  32],
#         ...,
#         [ 88,  87,  89],
#         [ 88,  87,  89],
#         [ 87,  86,  90]],
#
#        [[ 33,  31,  31],
#         [ 32,  30,  30],
#         [ 33,  31,  31],
# ...

# %%
img.shape
# Out:
# (427, 321, 3)

# %%
a= np.array([
    [1, 2, 3],
    [4, 5, 6]
])

print(a) #gib volles array aus

print(a.shape) #gib zeilen- und spaltenanzahl aus
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)

# %%
plt.imshow(img)
plt.show()
