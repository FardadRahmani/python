# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.2/38.8 MB 5.9 MB/s eta 0:00:07
#     --------------------------------------- 0.8/38.8 MB 10.1 MB/s eta 0:00:04
#    - -------------------------------------- 1.4/38.8 MB 11.2 MB/s eta 0:00:04
#    -- ------------------------------------- 2.0/38.8 MB 11.7 MB/s eta 0:00:04
#    -- ------------------------------------- 2.6/38.8 MB 12.0 MB/s eta 0:00:04
#    --- ------------------------------------ 3.2/38.8 MB 12.0 MB/s eta 0:00:03
#    --- ------------------------------------ 3.9/38.8 MB 12.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.5/38.8 MB 12.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.1/38.8 MB 12.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.7/38.8 MB 12.6 MB/s eta 0:00:03
# ...
